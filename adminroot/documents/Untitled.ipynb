# %%
import pandas as pd

# %%
data = pd.read_csv('flow.2001-09-29.csv')

# %%
data.describe()
# Out:
#         #:unix_secs  unix_nsecs     sysuptime          dpkts       doctets  \
# count  8.737330e+05    873733.0  8.737330e+05  873733.000000  8.737330e+05
# mean   1.285805e+09         0.0  2.442783e+09       4.440575  3.411165e+03
# std    8.674689e+01         0.0  8.675260e+04      44.602779  6.280848e+04
# min    1.285805e+09         0.0  2.442637e+09       1.000000  2.500000e+01
# 25%    1.285805e+09         0.0  2.442707e+09       1.000000  5.200000e+01
# 50%    1.285805e+09         0.0  2.442781e+09       1.000000  9.200000e+01
# 75%    1.285805e+09         0.0  2.442856e+09       2.000000  1.101000e+03
# max    1.285805e+09         0.0  2.442931e+09    9518.000000  1.393435e+07
#
#               first          last  engine_type  engine_id          input  \
# count  8.737330e+05  8.737330e+05     873733.0   873733.0  873733.000000
# mean   2.442724e+09  2.442731e+09          0.0        0.0     207.842700
# ...

# %% [markdown]
# *Q1* What is the average packet size, across all traffic in the trace? Describe how you
# computed this number.

# %%
sum(data.doctets)/sum(data.dpkts)
# Out:
# 768.18086011489538
